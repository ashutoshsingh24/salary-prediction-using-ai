# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('salary.csv')
print(df.head())
# Out:
#    Years of Experience        Salary
# 0                   25  106959.80570
# 1                   26  125038.02430
# 2                   28  132126.45780
# 3                   21   97541.39206
# 4                   12   63248.03888

# %%
df = pd.read_csv('salary.csv')
print(df.head())
# Out:
#    Years of Experience        Salary
# 0                   25  106959.80570
# 1                   26  125038.02430
# 2                   28  132126.45780
# 3                   21   97541.39206
# 4                   12   63248.03888

# %%
x=df[['Years of Experience']]
y=df['Salary']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(X_train_scaled, Y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
Y_pred = knn.predict(X_test_scaled)

mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Predicted Salaries: {Y_pred}")
print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Predicted Salaries: [138885.38476667 125212.64953333 113156.56133333 100180.09543333
#  125212.64953333  61261.14852     58746.31936667  62459.66476667
#  100180.09543333 138885.38476667 148901.92963333  80524.00092
#   90064.17915333 136990.64076667  12280.16585667  39175.53410667
#  107242.86896667 113156.56133333 113343.81073333 138885.38476667
#  113156.56133333 153089.4901     129383.5883     113156.56133333
#  180636.1374     136990.64076667  62459.66476667 125212.64953333
#  148901.92963333 138885.38476667  90064.17915333  95922.29978667
#  142345.30466667 160426.1488     129383.5883     100180.09543333
#  152060.5607      62459.66476667  54259.15137333  36631.55574667
#  113343.81073333  46710.49656667 108880.6233      76213.49045333
#   90064.17915333 117789.35956667 113343.81073333  36631.55574667
#   95922.29978667 108880.6233     125212.64953333 100180.09543333
#   95922.29978667 100180.09543333 113156.56133333 125212.64953333
#  113343.81073333 138885.38476667  34653.23355333 136990.64076667
#  113343.81073333 142345.30466667 108880.6233     125212.64953333
#  136990.64076667  80524.00092    107242.86896667 100180.09543333
#  148901.92963333  61261.14852     62459.66476667  88536.37567333
#  160426.1488      90064.17915333 107242.86896667 138885.38476667
#  160426.1488      88536.37567333 100180.09543333 100180.09543333
#  108880.6233     107242.86896667 136990.64076667 108880.6233
#  113343.81073333 138885.38476667  46710.49656667 125212.64953333
#  113343.81073333 153089.4901      90064.17915333 107242.86896667
#  117789.35956667  70244.22218667 113156.56133333 113343.81073333
#  129383.5883     136990.64076667  80524.00092     90064.17915333]
# Mean Squared Error: 35478362.59345825
# R² Score: 0.9689448535694544

# %%
years_exp = float(input("Enter years of experience: "))

input_scaled = scaler.transform([[years_exp]])
predicted_salary = knn.predict(input_scaled)

print(f"Predicted Salary for {years_exp} years of experience: ₹{predicted_salary[0]:,.2f}")
# Out:
# Enter years of experience:  20
# Predicted Salary for 20.0 years of experience: ₹95,922.30
# C:\Users\singh\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
